# %% [markdown]
# # Revised local research run
# Read README.md and METHODOLOGY.md first. Run from the repository root. The included universe has known selection bias. The command below explicitly records this limitation. Change the run directory for a new experiment.

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "scripts.run_research", "--run-dir", "runs/v2_notebook_01", "--allow-legacy-universe"], check=True)
