# %% [markdown]
# # Jupyter module workflow
#
# Use **Python 3.12 (Pairs Trading)** for every notebook. Run each module using **Run All**, in the order below. Files are saved automatically in `data/processed/current/`.

# %%
# %pip install -r requirements-notebooks.txt

# %% [markdown]
# ## Your results
#
# No run name or manifest is needed. Module 01 saves your settings; later notebooks load ordinary saved files from `data/processed/current/`. Rerunning a module overwrites its own outputs. After upstream changes, rerun downstream modules. Files are not automatically checked for freshness.
#
# Modules 04 and 06 are previews; Module 07 performs the daily backtest. Module 12 recalculates all placebo draws each time, without checkpoint reuse. Run one notebook at a time. Copy the results folder if you want to preserve an earlier experiment.
#
# The included universe remains historically filtered and options are model-valued. Review results before updating the thesis.

# %%
import sys
from pathlib import Path

print("Python:", sys.version)
print("Environment:", sys.executable)
print("Folder:", Path.cwd())
print("Requirements found:", Path("requirements-notebooks.txt").exists())
