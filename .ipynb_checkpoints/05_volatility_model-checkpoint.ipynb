# %% [markdown]
# # 05 — EWMA Volatility Model
#
# Module 05 estimates the volatility input required for option pricing.
#
# For each equity leg:
#
# \[
# \sigma_t^2
# =
# \lambda\sigma_{t-1}^2
# +
# (1-\lambda)r_{t-1}^2,
# \]
#
# with:
#
# \[
# \lambda = 0.94.
# \]
#
# Annualized volatility is:
#
# \[
# \sigma_t^{ann}
# =
# \sqrt{252\sigma_t^2}.
# \]
#
# Under the standard EWMA forecasting assumption, expected future variance
# is flat across the Module 04 convergence horizon. Therefore Module 05
# supplies one current annualized volatility estimate for each stock, while
# Module 04 continues to determine the statistical convergence horizon.

# %%
# %load_ext autoreload
# %autoreload 2


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



from src.volatility_model import (
    log_returns,
    ewma_variance_series,
    fit_ewma,
    forecast_pair_leg_volatilities,
)

# %% [markdown]
# ## 1. Settings

# %%
EWMA_LAMBDA = 0.94
MIN_OBS = 60

# %% [markdown]
# ## 2. Load equity prices and Module 04 signals
#
# Adjust `PRICE_FILE` and `SIGNAL_FILE` if your project uses different filenames.

# %%
PRICE_FILE = ("data/processed/train_prices.parquet")

SIGNAL_FILE = ("data/processed/fou_current_signals.parquet")

prices = pd.read_parquet(PRICE_FILE)
current_signals = pd.read_parquet(SIGNAL_FILE)

prices.index = pd.to_datetime(prices.index)
prices = prices.sort_index()

print("Price matrix:", prices.shape)
print("Module 04 rows:", len(current_signals))
print(prices.index[:5])
# Out:
# Price matrix: (1759, 466)
# Module 04 rows: 40
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# ## 3. Keep only actionable Module 04 candidates

# %%
candidates = (
    current_signals[
        current_signals["statistical_signal"] == True
    ]
    .copy()
    .reset_index(drop=True)
)

print(
    f"Actionable statistical candidates: {len(candidates)}"
)

candidates[
    [
        "pair",
        "current_z",
        "selected_dte_trading_days",
    ]
]
# Out:
# Actionable statistical candidates: 9
#        pair  current_z  selected_dte_trading_days
# 0    SHW-HD  -2.280265                       61.0
# 1   ZTS-ABT  -1.916357                       82.0
# 2   MAS-LEN  -2.414675                       93.0
# 3   MCO-WTW  -2.746422                      104.0
# 4   RSG-AJG  -1.696617                       86.0
# 5  MCO-MSCI  -1.941628                       97.0
# 6   LYV-AXP  -2.174888                       96.0
# 7   CDW-MSI  -1.544401                       88.0
# 8    LH-AMP  -2.162157                      109.0

# %% [markdown]
# ## 4. Inspect EWMA volatility for one equity

# %%
row = candidates.iloc[0]

dep = row["dependent"]
indep = row["independent"]
horizon = int(
    row["selected_dte_trading_days"]
)

dep_returns = log_returns(
    prices[dep]
)

dep_variance = ewma_variance_series(
    returns=dep_returns,
    lambda_=EWMA_LAMBDA,
)

dep_annualized_vol = np.sqrt(
    252 * dep_variance
)

plt.figure(figsize=(10, 5))
plt.plot(
    dep_annualized_vol.index,
    dep_annualized_vol,
)
plt.xlabel("Date")
plt.ylabel("Annualized volatility")
plt.title(
    f"{dep} — EWMA volatility"
)
plt.show()

dep_result = fit_ewma(
    returns=dep_returns,
    lambda_=EWMA_LAMBDA,
    min_obs=MIN_OBS,
)

dep_result
# Out:
# EWMAResult(lambda_=0.94, daily_variance=0.0003348212000086585, daily_volatility=0.01829812012226006, annualized_volatility=0.29047365182092155, n_obs=1758)

# %% [markdown]
# ## 5. Estimate EWMA volatility for one pair

# %%
pair_result = forecast_pair_leg_volatilities(
    prices=prices,
    dependent=dep,
    independent=indep,
    horizon_days=horizon,
    lambda_=EWMA_LAMBDA,
    min_obs=MIN_OBS,
)

pair_result
# Out:
# {'dependent': 'SHW',
#  'independent': 'HD',
#  'horizon_days': 61,
#  'lambda': 0.94,
#  'dependent_annualized_volatility': 0.29047365182092155,
#  'independent_annualized_volatility': 0.2731996757783827,
#  'dependent_daily_variance': 0.0003348212000086585,
#  'independent_daily_variance': 0.000296182789069101,
#  'dependent_n_obs': 1758,
#  'independent_n_obs': 1758}

# %% [markdown]
# ## 6. Estimate volatility for every current statistical candidate

# %%
rows = []

for _, row in candidates.iterrows():

    dep = row["dependent"]
    indep = row["independent"]
    pair = row["pair"]

    horizon = int(
        row["selected_dte_trading_days"]
    )

    try:
        vol = forecast_pair_leg_volatilities(
            prices=prices,
            dependent=dep,
            independent=indep,
            horizon_days=horizon,
            lambda_=EWMA_LAMBDA,
            min_obs=MIN_OBS,
        )

        rows.append(
            {
                "pair": pair,
                "dependent": dep,
                "independent": indep,
                "current_z": row["current_z"],
                "direction": row["direction"],
                "convergence_horizon_trading_days":
                    horizon,
                "convergence_horizon_calendar_days":
                    row["selected_dte_calendar_days"],
                **vol,
            }
        )

    except Exception as exc:
        print(
            f"Skipped {pair}: {exc}"
        )

volatility_forecasts = pd.DataFrame(
    rows
)

volatility_forecasts
# Out:
#        pair dependent independent  current_z  direction  \
# 0    SHW-HD       SHW          HD  -2.280265         -1
# 1   ZTS-ABT       ZTS         ABT  -1.916357         -1
# 2   MAS-LEN       MAS         LEN  -2.414675         -1
# 3   MCO-WTW       MCO         WTW  -2.746422         -1
# 4   RSG-AJG       RSG         AJG  -1.696617         -1
# 5  MCO-MSCI       MCO        MSCI  -1.941628         -1
# 6   LYV-AXP       LYV         AXP  -2.174888         -1
# 7   CDW-MSI       CDW         MSI  -1.544401         -1
# 8    LH-AMP        LH         AMP  -2.162157         -1
#
#    convergence_horizon_trading_days  convergence_horizon_calendar_days  \
# 0                                61                               89.0
# 1                                82                              119.0
# 2                                93                              135.0
# 3                               104                              151.0
# 4                                86                              125.0
# 5                                97                              141.0
# 6                                96                              140.0
# 7                                88                              128.0
# 8                               109                              158.0
#
#    horizon_days  lambda  dependent_annualized_volatility  \
# 0            61    0.94                         0.290474
# 1            82    0.94                         0.324660
# 2            93    0.94                         0.347549
# 3           104    0.94                         0.371192
# 4            86    0.94                         0.185075
# 5            97    0.94                         0.371192
# 6            96    0.94                         0.357970
# 7            88    0.94                         0.274834
# 8           109    0.94                         0.250088
#
#    independent_annualized_volatility  dependent_daily_variance  \
# 0                           0.273200                  0.000335
# 1                           0.231393                  0.000418
# 2                           0.338222                  0.000479
# 3                           0.183174                  0.000547
# 4                           0.213293                  0.000136
# 5                           0.382830                  0.000547
# 6                           0.261306                  0.000509
# 7                           0.253528                  0.000300
# 8                           0.255451                  0.000248
#
#    independent_daily_variance  dependent_n_obs  independent_n_obs
# 0                    0.000296             1758               1758
# 1                    0.000212             1758               1758
# 2                    0.000454             1758               1758
# 3                    0.000133             1758               1758
# 4                    0.000181             1758               1758
# 5                    0.000582             1758               1758
# 6                    0.000271             1758               1758
# 7                    0.000255             1758               1758
# 8                    0.000259             1758               1758

# %% [markdown]
# ## 7. Sanity checks
#
# EWMA volatility must be positive and finite. The same fixed
# \(\lambda=0.94\) is used for every stock.

# %%
display_cols = [
    "pair",
    "convergence_horizon_trading_days",
    "dependent_annualized_volatility",
    "independent_annualized_volatility",
    "lambda",
]

volatility_forecasts[
    display_cols
]
# Out:
#        pair  convergence_horizon_trading_days  \
# 0    SHW-HD                                61
# 1   ZTS-ABT                                82
# 2   MAS-LEN                                93
# 3   MCO-WTW                               104
# 4   RSG-AJG                                86
# 5  MCO-MSCI                                97
# 6   LYV-AXP                                96
# 7   CDW-MSI                                88
# 8    LH-AMP                               109
#
#    dependent_annualized_volatility  independent_annualized_volatility  lambda
# 0                         0.290474                           0.273200    0.94
# 1                         0.324660                           0.231393    0.94
# 2                         0.347549                           0.338222    0.94
# 3                         0.371192                           0.183174    0.94
# 4                         0.185075                           0.213293    0.94
# 5                         0.371192                           0.382830    0.94
# 6                         0.357970                           0.261306    0.94
# 7                         0.274834                           0.253528    0.94
# 8                         0.250088                           0.255451    0.94

# %%
volatility_forecasts[
    [
        "dependent_annualized_volatility",
        "independent_annualized_volatility",
    ]
].describe()
# Out:
#        dependent_annualized_volatility  independent_annualized_volatility
# count                         9.000000                           9.000000
# mean                          0.308115                           0.265822
# std                           0.063439                           0.061280
# min                           0.185075                           0.183174
# 25%                           0.274834                           0.231393
# 50%                           0.324660                           0.255451
# 75%                           0.357970                           0.273200
# max                           0.371192                           0.382830

# %%
assert (
    volatility_forecasts[
        "dependent_annualized_volatility"
    ] > 0
).all()

assert (
    volatility_forecasts[
        "independent_annualized_volatility"
    ] > 0
).all()

assert np.isfinite(
    volatility_forecasts[
        "dependent_annualized_volatility"
    ]
).all()

assert np.isfinite(
    volatility_forecasts[
        "independent_annualized_volatility"
    ]
).all()

assert (
    volatility_forecasts["lambda"]
    == EWMA_LAMBDA
).all()

# %% [markdown]
# ## 8. Save Module 05 output

# %%
OUTPUT = ("data/processed/volatility_forecasts.parquet"
)

volatility_forecasts.to_parquet(
    OUTPUT,
    index=False,
)

print(
    f"Saved: {OUTPUT}"
)
# Out:
# Saved: data/processed/volatility_forecasts.parquet
