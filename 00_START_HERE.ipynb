# %% [markdown]
# # Jupyter module workflow
#
# Open these notebooks in order and select **Run All** in each. No command-line pipeline is needed. Each module saves files for the next, even after restarting Jupyter.
#
# ## One-time setup
# Run the installation cell below once if dependencies are missing or you are using a new environment. Then choose **Kernel → Restart Kernel** before opening Module 01. This installs into the current notebook kernel environment.

# %%
# %pip install -r requirements-notebooks.txt

# %% [markdown]
# ## Run order
#
# 1. `01_Stock_Data.ipynb` — run name, settings and price split
# 2. `01_RF_Data.ipynb` — frozen rates and benchmark checks
# 3. `02_Pair_Selection.ipynb` — corrected cointegration selection
# 4. `03_fractional_OU.ipynb` — parameter estimation
# 5. `03_pair_eligibility.ipynb` — structural horizons and selected portfolio
# 6. `04_convergence_signal.ipynb` — one-date signal inspection
# 7. `05_volatility_model.ipynb` — lagged EWMA volatility
# 8. `06_option_pricing.ipynb` — next-close option preview
# 9. `07_backtest.ipynb` — complete daily backtest
# 10. `08_drawdown_diagnostics.ipynb` — drawdown and trade outcomes
# 11. `09_systematic_risk_diagnostics.ipynb` — consistent market exposure
# 12. `10_equilibrium_shift_diagnostics.ipynb` — frozen-equilibrium diagnostics
# 13. `11_static_convergence_calibration.ipynb` — path-based forecast calibration
# 14. `12_alpha_validation.ipynb` — alpha, bootstrap and checkpointed placebos
#
# ## Your results
#
# Defaults save in `runs/jupyter_v2_01`. Settings are chosen only in Module 01. Later notebooks automatically use the saved run. To begin a different experiment, change RUN_NAME in Module 01 before running it. A message names any prerequisite you have not completed. If you repeat an earlier module, run the later modules again to confirm their outputs.
#
# Modules 04 and 06 are explanatory snapshots; Module 07 recalculates signals and prices through the entire test period using the same functions. Empty snapshots are valid. Modules 08–11 do not rerun the portfolio. Module 12 can resume completed placebo checkpoints after interruption. Run one notebook at a time; do not run modules concurrently.
#
# The included stock universe remains historically filtered and options remain model-valued. These limitations are recorded in the manifest. The revised methodology is in METHODOLOGY.md. Send the output folder for review before updating the thesis.

# %%
import sys
from pathlib import Path

print("Python:", sys.version)
print("Environment:", sys.executable)
print("Folder:", Path.cwd())
print("Requirements found:", Path("requirements-notebooks.txt").exists())
