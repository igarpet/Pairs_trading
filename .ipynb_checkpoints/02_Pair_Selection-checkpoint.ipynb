# %%
import pandas as pd

# %%
from src.Pair_Selection import *
from src.Cointegration import find_cointegrated_pairs

prices = load_prices("data/processed/prices.parquet")

split = int(len(prices)*0.7)

train_prices = prices.iloc[:split]
test_prices = prices.iloc[split:]

returns = compute_returns(test_prices)

corr = correlation_matrix(returns)

candidate_pairs = generate_candidate_pairs(
    corr,
    top_n=10
)

candidate_summary(candidate_pairs)

candidate_pairs[:20]


cointegrated_pairs, spreads = find_cointegrated_pairs(
    train_prices,
    candidate_pairs,
    significance=0.01
)

print(cointegrated_pairs.head())
print(f"\nCointegrated pairs found: {len(cointegrated_pairs)}")
# Out:
# ============================================================
# PAIR SELECTION SUMMARY
# ============================================================
# Candidate pairs : 3,738
# ============================================================
# 100%|██████████| 3738/3738 [05:11<00:00, 11.99it/s]
#   dependent independent     alpha      beta       adf    pvalue
# 0       SHW          HD -0.580495  1.084491 -5.474267  0.000002
# 1      ORCL         ETN  0.640542  0.742037 -4.993938  0.000023
# 2      SPGI         ICE -1.358285  1.542537 -4.985110  0.000024
# 3       ETN         JBL  1.246885  0.904839 -4.947990  0.000028
# 4      NDSN        ODFL  2.783512  0.528448 -4.928276  0.000031
#
# Cointegrated pairs found: 446

# %%
import matplotlib.pyplot as plt

print(cointegrated_pairs["pvalue"].describe())
plt.hist(cointegrated_pairs["pvalue"], bins = 30)
plt.show()
# Out:
# count    446.000000
# mean       0.004375
# std        0.002987
# min        0.000002
# 25%        0.001619
# 50%        0.004292
# 75%        0.006726
# max        0.009958
# Name: pvalue, dtype: float64

# %%
train_prices.index = pd.to_datetime(train_prices.index)
test_prices.index = pd.to_datetime(test_prices.index)
print(train_prices.index[:5])
print(test_prices.index[:5])
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2022-12-28', '2022-12-29', '2022-12-30', '2023-01-03',
#                '2023-01-04'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
train_prices.to_parquet("data/processed/train_prices.parquet", index = False)
test_prices.to_parquet("data/processed/test_prices.parquet", index = False)
cointegrated_pairs.to_parquet("data/processed/cointegrated_pairs.parquet", index = False)

# %%
import pickle 
with open("data/processed/spreads.pkl", "wb") as f:
    pickle.dump(spreads, f)
